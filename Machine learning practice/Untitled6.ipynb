# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
cancer  = datasets.load_breast_cancer()

# %%
print(cancer.keys())
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %%
print(cancer.DESCR)
# Out:
# .. _breast_cancer_dataset:
#
# Breast cancer wisconsin (diagnostic) dataset
# --------------------------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 569
#
#     :Number of Attributes: 30 numeric, predictive attributes and the class
#
#     :Attribute Information:
#         - radius (mean of distances from center to points on the perimeter)
#         - texture (standard deviation of gray-scale values)
#         - perimeter
#         - area
#         - smoothness (local variation in radius lengths)
#         - compactness (perimeter^2 / area - 1.0)
#         - concavity (severity of concave portions of the contour)
#         - concave points (number of concave portions of the contour)
#         - symmetry
#         - fractal dimension ("coastline approximation" - 1)
#
#         The mean, standard error, and "worst" or largest (mean of the three
#         largest values) of these features were computed for each image,
#         resulting in 30 features.  For instance, field 3 is Mean Radius, field
#         13 is Radius SE, field 23 is Worst Radius.
#
#         - class:
#                 - WDBC-Malignant
#                 - WDBC-Benign
#
#     :Summary Statistics:
#
#     ===================================== ====== ======
#                                            Min    Max
#     ===================================== ====== ======
#     radius (mean):                        6.981  28.11
#     texture (mean):                       9.71   39.28
#     perimeter (mean):                     43.79  188.5
#     area (mean):                          143.5  2501.0
#     smoothness (mean):                    0.053  0.163
#     compactness (mean):                   0.019  0.345
#     concavity (mean):                     0.0    0.427
#     concave points (mean):                0.0    0.201
#     symmetry (mean):                      0.106  0.304
#     fractal dimension (mean):             0.05   0.097
#     radius (standard error):              0.112  2.873
#     texture (standard error):             0.36   4.885
#     perimeter (standard error):           0.757  21.98
#     area (standard error):                6.802  542.2
#     smoothness (standard error):          0.002  0.031
#     compactness (standard error):         0.002  0.135
#     concavity (standard error):           0.0    0.396
#     concave points (standard error):      0.0    0.053
#     symmetry (standard error):            0.008  0.079
#     fractal dimension (standard error):   0.001  0.03
#     radius (worst):                       7.93   36.04
#     texture (worst):                      12.02  49.54
#     perimeter (worst):                    50.41  251.2
#     area (worst):                         185.2  4254.0
#     smoothness (worst):                   0.071  0.223
#     compactness (worst):                  0.027  1.058
#     concavity (worst):                    0.0    1.252
#     concave points (worst):               0.0    0.291
#     symmetry (worst):                     0.156  0.664
#     fractal dimension (worst):            0.055  0.208
#     ===================================== ====== ======
#
#     :Missing Attribute Values: None
#
#     :Class Distribution: 212 - Malignant, 357 - Benign
#
#     :Creator:  Dr. William H. Wolberg, W. Nick Street, Olvi L. Mangasarian
#
#     :Donor: Nick Street
#
#     :Date: November, 1995
#
# This is a copy of UCI ML Breast Cancer Wisconsin (Diagnostic) datasets.
# https://goo.gl/U2Uwz2
#
# Features are computed from a digitized image of a fine needle
# aspirate (FNA) of a breast mass.  They describe
# characteristics of the cell nuclei present in the image.
#
# Separating plane described above was obtained using
# Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree
# Construction Via Linear Programming." Proceedings of the 4th
# Midwest Artificial Intelligence and Cognitive Science Society,
# pp. 97-101, 1992], a classification method which uses linear
# programming to construct a decision tree.  Relevant features
# were selected using an exhaustive search in the space of 1-4
# features and 1-3 separating planes.
#
# The actual linear program used to obtain the separating plane
# in the 3-dimensional space is that described in:
# [K. P. Bennett and O. L. Mangasarian: "Robust Linear
# Programming Discrimination of Two Linearly Inseparable Sets",
# Optimization Methods and Software 1, 1992, 23-34].
#
# This database is also available through the UW CS ftp server:
#
# ftp ftp.cs.wisc.edu
# cd math-prog/cpo-dataset/machine-learn/WDBC/
#
# .. topic:: References
#
#    - W.N. Street, W.H. Wolberg and O.L. Mangasarian. Nuclear feature extraction
#      for breast tumor diagnosis. IS&T/SPIE 1993 International Symposium on
#      Electronic Imaging: Science and Technology, volume 1905, pages 861-870,
#      San Jose, CA, 1993.
#    - O.L. Mangasarian, W.N. Street and W.H. Wolberg. Breast cancer diagnosis and
#      prognosis via linear programming. Operations Research, 43(4), pages 570-577,
#      July-August 1995.
#    - W.H. Wolberg, W.N. Street, and O.L. Mangasarian. Machine learning techniques
#      to diagnose breast cancer from fine-needle aspirates. Cancer Letters 77 (1994)
#      163-171.

# %%
print(cancer.feature_names)
# Out:
# ['mean radius' 'mean texture' 'mean perimeter' 'mean area'
#  'mean smoothness' 'mean compactness' 'mean concavity'
#  'mean concave points' 'mean symmetry' 'mean fractal dimension'
#  'radius error' 'texture error' 'perimeter error' 'area error'
#  'smoothness error' 'compactness error' 'concavity error'
#  'concave points error' 'symmetry error' 'fractal dimension error'
#  'worst radius' 'worst texture' 'worst perimeter' 'worst area'
#  'worst smoothness' 'worst compactness' 'worst concavity'
#  'worst concave points' 'worst symmetry' 'worst fractal dimension']

# %%
print(cancer.data)
# Out:
# [[1.799e+01 1.038e+01 1.228e+02 ... 2.654e-01 4.601e-01 1.189e-01]
#  [2.057e+01 1.777e+01 1.329e+02 ... 1.860e-01 2.750e-01 8.902e-02]
#  [1.969e+01 2.125e+01 1.300e+02 ... 2.430e-01 3.613e-01 8.758e-02]
#  ...
#  [1.660e+01 2.808e+01 1.083e+02 ... 1.418e-01 2.218e-01 7.820e-02]
#  [2.060e+01 2.933e+01 1.401e+02 ... 2.650e-01 4.087e-01 1.240e-01]
#  [7.760e+00 2.454e+01 4.792e+01 ... 0.000e+00 2.871e-01 7.039e-02]]

# %%
df = pd.DataFrame(cancer.data, columns=cancer.feature_names)

# %%
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  mean compactness  \
# 0          17.99         10.38          122.80     1001.0             0.12              0.28
# 1          20.57         17.77          132.90     1326.0             0.08              0.08
# 2          19.69         21.25          130.00     1203.0             0.11              0.16
# 3          11.42         20.38           77.58      386.1             0.14              0.28
# 4          20.29         14.34          135.10     1297.0             0.10              0.13
# ..           ...           ...             ...        ...              ...               ...
# 564        21.56         22.39          142.00     1479.0             0.11              0.12
# 565        20.13         28.25          131.20     1261.0             0.10              0.10
# 566        16.60         28.08          108.30      858.1             0.08              0.10
# 567        20.60         29.33          140.10     1265.0             0.12              0.28
# 568         7.76         24.54           47.92      181.0             0.05              0.04
#
#      mean concavity  mean concave points  mean symmetry  mean fractal dimension  ...  \
# 0              0.30                 0.15           0.24                    0.08  ...
# 1              0.09                 0.07           0.18                    0.06  ...
# 2              0.20                 0.13           0.21                    0.06  ...
# 3              0.24                 0.11           0.26                    0.10  ...
# 4              0.20                 0.10           0.18                    0.06  ...
# ..              ...                  ...            ...                     ...  ...
# 564            0.24                 0.14           0.17                    0.06  ...
# 565            0.14                 0.10           0.18                    0.06  ...
# 566            0.09                 0.05           0.16                    0.06  ...
# 567            0.35                 0.15           0.24                    0.07  ...
# 568            0.00                 0.00           0.16                    0.06  ...
#
#      worst radius  worst texture  worst perimeter  worst area  worst smoothness  \
# 0           25.38          17.33           184.60      2019.0              0.16
# 1           24.99          23.41           158.80      1956.0              0.12
# 2           23.57          25.53           152.50      1709.0              0.14
# 3           14.91          26.50            98.87       567.7              0.21
# 4           22.54          16.67           152.20      1575.0              0.14
# ..            ...            ...              ...         ...               ...
# 564         25.45          26.40           166.10      2027.0              0.14
# 565         23.69          38.25           155.00      1731.0              0.12
# 566         18.98          34.12           126.70      1124.0              0.11
# 567         25.74          39.42           184.60      1821.0              0.17
# 568          9.46          30.37            59.16       268.6              0.09
#
#      worst compactness  worst concavity  worst concave points  worst symmetry  \
# 0                 0.67             0.71                  0.27            0.46
# 1                 0.19             0.24                  0.19            0.28
# 2                 0.42             0.45                  0.24            0.36
# 3                 0.87             0.69                  0.26            0.66
# 4                 0.20             0.40                  0.16            0.24
# ..                 ...              ...                   ...             ...
# 564               0.21             0.41                  0.22            0.21
# 565               0.19             0.32                  0.16            0.26
# 566               0.31             0.34                  0.14            0.22
# 567               0.87             0.94                  0.27            0.41
# 568               0.06             0.00                  0.00            0.29
#
#      worst fractal dimension
# 0                       0.12
# 1                       0.09
# 2                       0.09
# 3                       0.17
# 4                       0.08
# ..                       ...
# 564                     0.07
# 565                     0.07
# 566                     0.08
# 567                     0.12
# 568                     0.07
#
# [569 rows x 30 columns]

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter  mean area  mean smoothness  mean compactness  \
# count       569.00        569.00          569.00     569.00           569.00            569.00
# mean         14.13         19.29           91.97     654.89             0.10              0.10
# std           3.52          4.30           24.30     351.91             0.01              0.05
# min           6.98          9.71           43.79     143.50             0.05              0.02
# 25%          11.70         16.17           75.17     420.30             0.09              0.06
# 50%          13.37         18.84           86.24     551.10             0.10              0.09
# 75%          15.78         21.80          104.10     782.70             0.11              0.13
# max          28.11         39.28          188.50    2501.00             0.16              0.35
#
#        mean concavity  mean concave points  mean symmetry  mean fractal dimension  ...  \
# count          569.00               569.00         569.00                5.69e+02  ...
# mean             0.09                 0.05           0.18                6.28e-02  ...
# std              0.08                 0.04           0.03                7.06e-03  ...
# min              0.00                 0.00           0.11                5.00e-02  ...
# 25%              0.03                 0.02           0.16                5.77e-02  ...
# 50%              0.06                 0.03           0.18                6.15e-02  ...
# 75%              0.13                 0.07           0.20                6.61e-02  ...
# max              0.43                 0.20           0.30                9.74e-02  ...
#
#        worst radius  worst texture  worst perimeter  worst area  worst smoothness  \
# count        569.00         569.00           569.00      569.00            569.00
# mean          16.27          25.68           107.26      880.58              0.13
# std            4.83           6.15            33.60      569.36              0.02
# min            7.93          12.02            50.41      185.20              0.07
# 25%           13.01          21.08            84.11      515.30              0.12
# 50%           14.97          25.41            97.66      686.50              0.13
# 75%           18.79          29.72           125.40     1084.00              0.15
# max           36.04          49.54           251.20     4254.00              0.22
#
#        worst compactness  worst concavity  worst concave points  worst symmetry  \
# count             569.00           569.00                569.00          569.00
# mean                0.25             0.27                  0.11            0.29
# std                 0.16             0.21                  0.07            0.06
# min                 0.03             0.00                  0.00            0.16
# 25%                 0.15             0.11                  0.06            0.25
# 50%                 0.21             0.23                  0.10            0.28
# 75%                 0.34             0.38                  0.16            0.32
# max                 1.06             1.25                  0.29            0.66
#
#        worst fractal dimension
# count                   569.00
# mean                      0.08
# std                       0.02
# min                       0.06
# 25%                       0.07
# 50%                       0.08
# 75%                       0.09
# max                       0.21
#
# [8 rows x 30 columns]

# %%
df.dtypes
# Out:
# mean radius                float64
# mean texture               float64
# mean perimeter             float64
# mean area                  float64
# mean smoothness            float64
# mean compactness           float64
# mean concavity             float64
# mean concave points        float64
# mean symmetry              float64
# mean fractal dimension     float64
# radius error               float64
# texture error              float64
# perimeter error            float64
# area error                 float64
# smoothness error           float64
# compactness error          float64
# concavity error            float64
# concave points error       float64
# symmetry error             float64
# fractal dimension error    float64
# worst radius               float64
# worst texture              float64
# worst perimeter            float64
# worst area                 float64
# worst smoothness           float64
# worst compactness          float64
# worst concavity            float64
# worst concave points       float64
# worst symmetry             float64
# worst fractal dimension    float64
# dtype: object

# %%
print(df.corr())
# Out:
#                          mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# mean radius                 1.00e+00      3.24e-01        9.98e-01   9.87e-01             0.17
# mean texture                3.24e-01      1.00e+00        3.30e-01   3.21e-01            -0.02
# mean perimeter              9.98e-01      3.30e-01        1.00e+00   9.87e-01             0.21
# mean area                   9.87e-01      3.21e-01        9.87e-01   1.00e+00             0.18
# mean smoothness             1.71e-01     -2.34e-02        2.07e-01   1.77e-01             1.00
# mean compactness            5.06e-01      2.37e-01        5.57e-01   4.99e-01             0.66
# mean concavity              6.77e-01      3.02e-01        7.16e-01   6.86e-01             0.52
# mean concave points         8.23e-01      2.93e-01        8.51e-01   8.23e-01             0.55
# mean symmetry               1.48e-01      7.14e-02        1.83e-01   1.51e-01             0.56
# mean fractal dimension     -3.12e-01     -7.64e-02       -2.61e-01  -2.83e-01             0.58
# radius error                6.79e-01      2.76e-01        6.92e-01   7.33e-01             0.30
# texture error              -9.73e-02      3.86e-01       -8.68e-02  -6.63e-02             0.07
# perimeter error             6.74e-01      2.82e-01        6.93e-01   7.27e-01             0.30
# area error                  7.36e-01      2.60e-01        7.45e-01   8.00e-01             0.25
# smoothness error           -2.23e-01      6.61e-03       -2.03e-01  -1.67e-01             0.33
# compactness error           2.06e-01      1.92e-01        2.51e-01   2.13e-01             0.32
# concavity error             1.94e-01      1.43e-01        2.28e-01   2.08e-01             0.25
# concave points error        3.76e-01      1.64e-01        4.07e-01   3.72e-01             0.38
# symmetry error             -1.04e-01      9.13e-03       -8.16e-02  -7.25e-02             0.20
# fractal dimension error    -4.26e-02      5.45e-02       -5.52e-03  -1.99e-02             0.28
# worst radius                9.70e-01      3.53e-01        9.69e-01   9.63e-01             0.21
# worst texture               2.97e-01      9.12e-01        3.03e-01   2.87e-01             0.04
# worst perimeter             9.65e-01      3.58e-01        9.70e-01   9.59e-01             0.24
# worst area                  9.41e-01      3.44e-01        9.42e-01   9.59e-01             0.21
# worst smoothness            1.20e-01      7.75e-02        1.51e-01   1.24e-01             0.81
# worst compactness           4.13e-01      2.78e-01        4.56e-01   3.90e-01             0.47
# worst concavity             5.27e-01      3.01e-01        5.64e-01   5.13e-01             0.43
# worst concave points        7.44e-01      2.95e-01        7.71e-01   7.22e-01             0.50
# worst symmetry              1.64e-01      1.05e-01        1.89e-01   1.44e-01             0.39
# worst fractal dimension     7.07e-03      1.19e-01        5.10e-02   3.74e-03             0.50
#
#                          mean compactness  mean concavity  mean concave points  mean symmetry  \
# mean radius                          0.51            0.68                 0.82           0.15
# mean texture                         0.24            0.30                 0.29           0.07
# mean perimeter                       0.56            0.72                 0.85           0.18
# mean area                            0.50            0.69                 0.82           0.15
# mean smoothness                      0.66            0.52                 0.55           0.56
# mean compactness                     1.00            0.88                 0.83           0.60
# mean concavity                       0.88            1.00                 0.92           0.50
# mean concave points                  0.83            0.92                 1.00           0.46
# mean symmetry                        0.60            0.50                 0.46           1.00
# mean fractal dimension               0.57            0.34                 0.17           0.48
# radius error                         0.50            0.63                 0.70           0.30
# texture error                        0.05            0.08                 0.02           0.13
# perimeter error                      0.55            0.66                 0.71           0.31
# area error                           0.46            0.62                 0.69           0.22
# smoothness error                     0.14            0.10                 0.03           0.19
# compactness error                    0.74            0.67                 0.49           0.42
# concavity error                      0.57            0.69                 0.44           0.34
# concave points error                 0.64            0.68                 0.62           0.39
# symmetry error                       0.23            0.18                 0.10           0.45
# fractal dimension error              0.51            0.45                 0.26           0.33
# worst radius                         0.54            0.69                 0.83           0.19
# worst texture                        0.25            0.30                 0.29           0.09
# worst perimeter                      0.59            0.73                 0.86           0.22
# worst area                           0.51            0.68                 0.81           0.18
# worst smoothness                     0.57            0.45                 0.45           0.43
# worst compactness                    0.87            0.75                 0.67           0.47
# worst concavity                      0.82            0.88                 0.75           0.43
# worst concave points                 0.82            0.86                 0.91           0.43
# worst symmetry                       0.51            0.41                 0.38           0.70
# worst fractal dimension              0.69            0.51                 0.37           0.44
#
#                          mean fractal dimension  ...  worst radius  worst texture  \
# mean radius                           -3.12e-01  ...          0.97       2.97e-01
# mean texture                          -7.64e-02  ...          0.35       9.12e-01
# mean perimeter                        -2.61e-01  ...          0.97       3.03e-01
# mean area                             -2.83e-01  ...          0.96       2.87e-01
# mean smoothness                        5.85e-01  ...          0.21       3.61e-02
# mean compactness                       5.65e-01  ...          0.54       2.48e-01
# mean concavity                         3.37e-01  ...          0.69       3.00e-01
# mean concave points                    1.67e-01  ...          0.83       2.93e-01
# mean symmetry                          4.80e-01  ...          0.19       9.07e-02
# mean fractal dimension                 1.00e+00  ...         -0.25      -5.13e-02
# radius error                           1.11e-04  ...          0.72       1.95e-01
# texture error                          1.64e-01  ...         -0.11       4.09e-01
# perimeter error                        3.98e-02  ...          0.70       2.00e-01
# area error                            -9.02e-02  ...          0.76       1.96e-01
# smoothness error                       4.02e-01  ...         -0.23      -7.47e-02
# compactness error                      5.60e-01  ...          0.20       1.43e-01
# concavity error                        4.47e-01  ...          0.19       1.00e-01
# concave points error                   3.41e-01  ...          0.36       8.67e-02
# symmetry error                         3.45e-01  ...         -0.13      -7.75e-02
# fractal dimension error                6.88e-01  ...         -0.04      -3.20e-03
# worst radius                          -2.54e-01  ...          1.00       3.60e-01
# worst texture                         -5.13e-02  ...          0.36       1.00e+00
# worst perimeter                       -2.05e-01  ...          0.99       3.65e-01
# worst area                            -2.32e-01  ...          0.98       3.46e-01
# worst smoothness                       5.05e-01  ...          0.22       2.25e-01
# worst compactness                      4.59e-01  ...          0.48       3.61e-01
# worst concavity                        3.46e-01  ...          0.57       3.68e-01
# worst concave points                   1.75e-01  ...          0.79       3.60e-01
# worst symmetry                         3.34e-01  ...          0.24       2.33e-01
# worst fractal dimension                7.67e-01  ...          0.09       2.19e-01
#
#                          worst perimeter  worst area  worst smoothness  worst compactness  \
# mean radius                     9.65e-01        0.94              0.12               0.41
# mean texture                    3.58e-01        0.34              0.08               0.28
# mean perimeter                  9.70e-01        0.94              0.15               0.46
# mean area                       9.59e-01        0.96              0.12               0.39
# mean smoothness                 2.39e-01        0.21              0.81               0.47
# mean compactness                5.90e-01        0.51              0.57               0.87
# mean concavity                  7.30e-01        0.68              0.45               0.75
# mean concave points             8.56e-01        0.81              0.45               0.67
# mean symmetry                   2.19e-01        0.18              0.43               0.47
# mean fractal dimension         -2.05e-01       -0.23              0.50               0.46
# radius error                    7.20e-01        0.75              0.14               0.29
# texture error                  -1.02e-01       -0.08             -0.07              -0.09
# perimeter error                 7.21e-01        0.73              0.13               0.34
# area error                      7.61e-01        0.81              0.13               0.28
# smoothness error               -2.17e-01       -0.18              0.31              -0.06
# compactness error               2.61e-01        0.20              0.23               0.68
# concavity error                 2.27e-01        0.19              0.17               0.48
# concave points error            3.95e-01        0.34              0.22               0.45
# symmetry error                 -1.04e-01       -0.11             -0.01               0.06
# fractal dimension error        -1.00e-03       -0.02              0.17               0.39
# worst radius                    9.94e-01        0.98              0.22               0.48
# worst texture                   3.65e-01        0.35              0.23               0.36
# worst perimeter                 1.00e+00        0.98              0.24               0.53
# worst area                      9.78e-01        1.00              0.21               0.44
# worst smoothness                2.37e-01        0.21              1.00               0.57
# worst compactness               5.29e-01        0.44              0.57               1.00
# worst concavity                 6.18e-01        0.54              0.52               0.89
# worst concave points            8.16e-01        0.75              0.55               0.80
# worst symmetry                  2.69e-01        0.21              0.49               0.61
# worst fractal dimension         1.39e-01        0.08              0.62               0.81
#
#                          worst concavity  worst concave points  worst symmetry  \
# mean radius                         0.53                  0.74            0.16
# mean texture                        0.30                  0.30            0.11
# mean perimeter                      0.56                  0.77            0.19
# mean area                           0.51                  0.72            0.14
# mean smoothness                     0.43                  0.50            0.39
# mean compactness                    0.82                  0.82            0.51
# mean concavity                      0.88                  0.86            0.41
# mean concave points                 0.75                  0.91            0.38
# mean symmetry                       0.43                  0.43            0.70
# mean fractal dimension              0.35                  0.18            0.33
# radius error                        0.38                  0.53            0.09
# texture error                      -0.07                 -0.12           -0.13
# perimeter error                     0.42                  0.55            0.11
# area error                          0.39                  0.54            0.07
# smoothness error                   -0.06                 -0.10           -0.11
# compactness error                   0.64                  0.48            0.28
# concavity error                     0.66                  0.44            0.20
# concave points error                0.55                  0.60            0.14
# symmetry error                      0.04                 -0.03            0.39
# fractal dimension error             0.38                  0.22            0.11
# worst radius                        0.57                  0.79            0.24
# worst texture                       0.37                  0.36            0.23
# worst perimeter                     0.62                  0.82            0.27
# worst area                          0.54                  0.75            0.21
# worst smoothness                    0.52                  0.55            0.49
# worst compactness                   0.89                  0.80            0.61
# worst concavity                     1.00                  0.86            0.53
# worst concave points                0.86                  1.00            0.50
# worst symmetry                      0.53                  0.50            1.00
# worst fractal dimension             0.69                  0.51            0.54
#
#                          worst fractal dimension
# mean radius                             7.07e-03
# mean texture                            1.19e-01
# mean perimeter                          5.10e-02
# mean area                               3.74e-03
# mean smoothness                         4.99e-01
# mean compactness                        6.87e-01
# mean concavity                          5.15e-01
# mean concave points                     3.69e-01
# mean symmetry                           4.38e-01
# mean fractal dimension                  7.67e-01
# radius error                            4.96e-02
# texture error                          -4.57e-02
# perimeter error                         8.54e-02
# area error                              1.75e-02
# smoothness error                        1.01e-01
# compactness error                       5.91e-01
# concavity error                         4.39e-01
# concave points error                    3.11e-01
# symmetry error                          7.81e-02
# fractal dimension error                 5.91e-01
# worst radius                            9.35e-02
# worst texture                           2.19e-01
# worst perimeter                         1.39e-01
# worst area                              7.96e-02
# worst smoothness                        6.18e-01
# worst compactness                       8.10e-01
# worst concavity                         6.87e-01
# worst concave points                    5.11e-01
# worst symmetry                          5.38e-01
# worst fractal dimension                 1.00e+00
#
# [30 rows x 30 columns]
